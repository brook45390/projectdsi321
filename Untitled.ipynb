# %%
import pandas as pd
dfs = pd.read_html("https://docs.google.com/spreadsheets/d/e/2PACX-1vQlEs3FxFPwm-dpvU1YdsfRgsbfT9WdiXJHZm9kJgGTziPnk-y3TWtftbSbxj6Fe_g0NxYgqyVHTVU5/pubhtml?gid=1397577608&amp;single=true&amp;widget=true&amp;headers=false")
df = dfs[0]
df
# Out:
# c:\Users\DELL\.conda\envs\dsi202_2021\lib\site-packages\OpenSSL\_util.py:6: CryptographyDeprecationWarning: Python 3.6 is no longer supported by the Python core team. Therefore, support for it is deprecated in cryptography and will be removed in a future release.
#   from cryptography.hazmat.bindings.openssl.binding import Binding
#     Unnamed: 0          Unnamed: 1   Unnamed: 2         Unnamed: 3  \
# 0            1         retrived_at  province_id               city
# 1            2   4/27/2023 9:15:27        TH-10        Phra Nakhon
# 2            3   4/27/2023 9:15:58        TH-11          Bang Phli
# 3            4   4/27/2023 9:16:29        TH-12  Mueang Nonthaburi
# 4            5   4/27/2023 9:17:01        TH-13       Khlong Luang
# ..         ...                 ...          ...                ...
# 62          63  4/27/2023 14:18:34        TH-16             Ban Mi
# 63          64  4/27/2023 14:19:05        TH-20           Na Kluea
# 64          65  4/27/2023 14:19:36        TH-21           Ban Khai
# 65          66  4/27/2023 14:20:07        TH-50         Chiang Mai
# 66          67  4/27/2023 14:20:38        TH-52          Hang Chat
#
#       Unnamed: 4 Unnamed: 5     Unnamed: 6     Unnamed: 7  Unnamed: 8  \
# 0          state    country  pollution_aqi  polution_main  weather_tp
# 1        Bangkok   Thailand            105             p2          31
# 2   Samut Prakan   Thailand            135             p2          30
# 3     Nonthaburi   Thailand            135             p2          31
# 4   Pathum Thani   Thailand            128             p2          31
# ..           ...        ...            ...            ...         ...
# 62      Lop Buri   Thailand             70             p2          38
# 63     Chon Buri   Thailand            112             p2          34
# 64        Rayong   Thailand             89             p2          35
# 65    Chiang Mai   Thailand             92             p2          36
# 66       Lampang   Thailand             86             p2          39
#
#     Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0   weather_pr  weather_hu  weather_ws  weather_wd
# 1         1011          57        0.63         135
# 2         1011          74        1.03           0
# 3         1012          63        1.03           0
# 4         1012          75        1.03           0
# ..         ...         ...         ...         ...
# 62        1007          35        2.51         253
# 63        1008          61        4.86         237
# 64        1008          52        4.81         181
# 65         990          37        4.63         190
# 66        1007          35        1.33         176
#
# [67 rows x 13 columns]

# %%
df.to_csv('df.csv', index=False)
